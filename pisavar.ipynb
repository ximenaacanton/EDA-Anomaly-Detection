# %%
import pandas as pd

df = pd.read_csv('/Users/ximenacanton/Documents/TEC/4 SEM/ACD/pisa/df_CONTIFORM_MMA_CONTIFORM_MMA1_WS_Tot_Bottles_0.csv')
print(df.head())  # Muestra las primeras filas del dataframe
print(df.info())  # Información sobre el dataframe, tipos de columnas
# Out:
#                             user_ts  \
# 0  2024-10-31 12:00:00.840000+00:00
# 1  2024-10-31 12:00:01.841000+00:00
# 2  2024-10-31 12:00:02.841000+00:00
# 3  2024-10-31 12:00:03.842000+00:00
# 4  2024-10-31 12:00:04.885000+00:00
#
#                                         variable     value  \
# 0  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Bottles.0  276915.0
# 1  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Bottles.0  276925.0
# 2  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Bottles.0  276935.0
# 3  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Bottles.0  276944.0
# 4  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Bottles.0  276954.0
#
#    currentConsumption  totalConsumption
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755 entries, 0 to 1754
# Data columns (total 5 columns):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#EDA
print(df.describe())  # Estadísticas generales
print(df.info())  # Información de tipos de datos y valores nulos
print(df.isnull().sum())  # Revisión de valores nulos

#Distribución
sns.histplot(df["value"], bins=30, kde=True)
plt.title("Distribución de cvalue")
plt.show()



#Outliers
sns.boxplot(x=df["value"])
plt.show()

#Tendencias temporales
df.plot(x="user_ts", y="value", figsize=(10,5))
plt.show()
# Out:
#                value  currentConsumption  totalConsumption
# count    1755.000000                 0.0               0.0
# mean   285471.825071                 NaN               NaN
# std      4945.942351                 NaN               NaN
# min    276915.000000                 NaN               NaN
# 25%    281191.000000                 NaN               NaN
# 50%    285467.000000                 NaN               NaN
# 75%    289760.000000                 NaN               NaN
# max    294047.000000                 NaN               NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755 entries, 0 to 1754
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_ts             1755 non-null   object
#  1   variable            1755 non-null   object
#  2   value               1755 non-null   float64
#  3   currentConsumption  0 non-null      float64
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['value'])
plt.title('Boxplot de la variable "value"')
plt.show()

# %%
from scipy.stats import zscore

# Convertir a tipo numérico si no lo está
df['value'] = pd.to_numeric(df['value'], errors='coerce')

# Eliminar filas con NaN generados por la conversión
df = df.dropna(subset=['value'])

# Calcular Z-score
z_scores = zscore(df['value'])

# Detectar anomalías donde el Z-score es mayor que 3 o menor que -3
anomalies_z = df[abs(z_scores) > 3]

print(anomalies_z)
# Out:
# Empty DataFrame
# Columns: [user_ts, variable, value, currentConsumption, totalConsumption]
# Index: []

# %%
df = pd.read_csv('/Users/ximenacanton/Documents/TEC/4 SEM/ACD/pisa/df_CONTIFORM_MMA_CONTIFORM_MMA1_WS_Tot_Rej_0.csv')
print(df.head())  # Muestra las primeras filas del dataframe
print(df.info())  # Información sobre el dataframe, tipos de columnas
# Out:
#                             user_ts  \
# 0  2024-10-31 12:06:21.485000+00:00
# 1  2024-10-31 12:06:27.490000+00:00
# 2  2024-10-31 12:06:28.488000+00:00
# 3  2024-10-31 12:07:02.515000+00:00
# 4  2024-10-31 12:07:05.666000+00:00
#
#                                     variable   value  currentConsumption  \
# 0  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2038.0                 NaN
# 1  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2041.0                 NaN
# 2  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2044.0                 NaN
# 3  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2045.0                 NaN
# 4  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2048.0                 NaN
#
#    totalConsumption
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ...

# %%
#EDA
print(df.describe())  # Estadísticas generales
print(df.info())  # Información de tipos de datos y valores nulos
print(df.isnull().sum())  # Revisión de valores nulos

#Distribución
sns.histplot(df["value"], bins=30, kde=True,color="pink")
plt.title("Distribución de cvalue")
plt.show()



#Outliers
sns.boxplot(x=df["value"],color="pink")
plt.show()

#Tendencias temporales
df.plot(x="user_ts", y="value", figsize=(10,5),color="pink")
plt.show()
# Out:
#              value  currentConsumption  totalConsumption
# count    14.000000                 0.0               0.0
# mean   2106.357143                 NaN               NaN
# std     109.575831                 NaN               NaN
# min    2038.000000                 NaN               NaN
# 25%    2045.750000                 NaN               NaN
# 50%    2055.500000                 NaN               NaN
# 75%    2065.250000                 NaN               NaN
# max    2311.000000                 NaN               NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_ts             14 non-null     datetime64[ns, UTC]
#  1   variable            14 non-null     object
#  2   value               14 non-null     float64
#  3   currentConsumption  0 non-null      float64
# ...

# %%
# Estadísticas descriptivas avanzadas
desc_stats = df['value'].describe()
skewness = df['value'].skew()  # Asimetría
kurtosis = df['value'].kurtosis()  # Curtosis

print("Estadísticas descriptivas:\n", desc_stats)
print("Asimetría:", skewness)
print("Curtosis:", kurtosis)
# Out:
# Estadísticas descriptivas:
#  count      1755.000000
# mean     285471.825071
# std        4945.942351
# min      276915.000000
# 25%      281191.000000
# 50%      285467.000000
# 75%      289760.000000
# max      294047.000000
# Name: value, dtype: float64
# Asimetría: 0.0024255492047670466
# Curtosis: -1.2014911828648243

# %%
# Gráfico de densidad
plt.figure(figsize=(10, 6))
sns.kdeplot(df['value'], shade=True)
plt.title('Distribución de "value" con Gráfico de Densidad')
plt.xlabel('Valor')
plt.ylabel('Densidad')
plt.show()
# Out:
# /var/folders/xl/hd09kyc55l54dqs59vtq831h0000gn/T/ipykernel_57467/1572082042.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_filtered['value'], shade=True)

# %%
import scipy.stats as stats

# QQ plot para comprobar normalidad
plt.figure(figsize=(10, 6))
stats.probplot(df['value'], dist="norm", plot=plt)
plt.title('QQ Plot de "value"')
plt.show()

# %%
# Mostrar las columnas del DataFrame
print(df.columns)
# Out:
# Index(['user_ts', 'variable', 'value', 'currentConsumption',
#        'totalConsumption'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Asegúrate de que 'user_ts' sea de tipo datetime
df['user_ts'] = pd.to_datetime(df['user_ts'])

# Graficar la variable 'value' a lo largo del tiempo
plt.figure(figsize=(10, 6))
plt.plot(df['user_ts'], df['value'], marker='o', color='pink')
plt.title('Tendencia de "value" a lo largo del tiempo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
Q1 = df['value'].quantile(0.25)
Q3 = df['value'].quantile(0.75)
IQR = Q3 - Q1

# Definir los límites de los outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identificar outliers
anomalies = df[(df['value'] < lower_bound) | (df['value'] > upper_bound)]

print("Anomalías detectadas:")
print(anomalies)
# Out:
# Anomalías detectadas:
#                             user_ts  \
# 11 2024-10-31 12:24:47.890000+00:00
# 12 2024-10-31 12:41:59.139000+00:00
# 13 2024-10-31 12:42:00.139000+00:00
#
#                                      variable   value  currentConsumption  \
# 11  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2305.0                 NaN
# 12  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2308.0                 NaN
# 13  CONTIFORM_MMA.CONTIFORM_MMA1.WS_Tot_Rej.0  2311.0                 NaN
#
#     totalConsumption   z_score
# 11               NaN  1.881267
# 12               NaN  1.909679
# 13               NaN  1.938091
